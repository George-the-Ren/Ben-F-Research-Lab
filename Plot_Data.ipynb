# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
# %matplotlib inline

# %%
file = '/Users/Grant/Desktop/research/lat_long.csv'
df = pd.read_csv(file, index_col=0)
df.head()
# Out:
#     latitude   longitude                                            address
# 0  33.960050 -118.264467  626, East Manchester Avenue, Florence, Los Ang...
# 1  33.987843 -118.230181  5968, Santa Fe Avenue, Huntington Park, Los An...
# 2  33.960065 -118.240581  1804, Firestone Boulevard, Nadeau, Firestone P...
# 3  34.041848 -118.245602  San Pedro Street, Skid Row, Little Tokyo Histo...
# 4  34.041848 -118.245602  San Pedro Street, Skid Row, Little Tokyo Histo...

# %%
location = df[['latitude', 'longitude']]
list_df = location.values.tolist()
list_df[0:10]
# Out:
# [[33.9600503877551, -118.26446704081631],
#  [33.98784267346939, -118.23018061224491],
#  [33.9600645, -118.240581],
#  [34.0418484, -118.24560179999999],
#  [34.0418484, -118.24560179999999],
#  [33.9741097, -118.2346135],
#  [34.0536909, -118.2427666],
#  [33.9641684, -118.27830049999999],
#  [33.9641684, -118.27830049999999],
#  [33.974389, -118.22796714285714]]

# %%
la_map = folium.Map(location=[34, -118.35], zoom_start=12)
address = df['address']
for point in range(0, len(list_df)):
    folium.CircleMarker(list_df[point], popup=address[point], 
                        radius=2, fill=True, color='blue').add_to(la_map)
la_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
x = df['latitude']
y = df['longitude']
plt.figure(figsize=(10,8))
plt.scatter(x, y)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('LA Data')
plt.tight_layout()
plt.xlim((33.8, 34.25))
# plt.ylim((-118.55, -118.15))
plt.show()
